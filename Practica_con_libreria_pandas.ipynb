# %%
#CONECTAR CON GOOGLE DRIVE
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##CONSULTAR LA CODIFICACION DE UN ARCHIVO CSV
#
# import chardet
#
# with open('datos.csv', 'rb') as file:
#     print(chardet.detect(file.read()))
#
#
# EJEMPLO DE RESPUESTA:
#
# {'encoding': 'UTF-16', 'confidence': 1.0, 'language': ''}
#
#
# CODIGO PARA LEER EL ARCHIVO CON PANDAS Y LA CODIFICACION INDICADA:
#
# df = pd.read_csv('datos.csv', encoding='UTF-16')

# %%
#CONMSULTAR EL CSV

import pandas as pd

url = '/content/drive/MyDrive/CURSO_ALURA/Cruso Pandas E-S: trabajando con diferentes formatos de archivo Pandas E-S: trabajando con diferentes formatos de archivo/superstore_data.csv'

pd.read_csv(url)
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
#CONSULTAR LAS PRIMERA LINEAS

datos_primeras_lineas = pd.read_csv(url,nrows=5)

datos_primeras_lineas
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %%
#CONSULTAR LAS COLUMNAS Id, Year_Bird, Income POR NOMBRE

datos_seleccion = pd.read_csv(url, usecols=['Id','Year_Birth','Income'])

datos_seleccion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
#CONSULTAR LAS COLUMNAS Id, Year_Bird, Income POR indice

datos_seleccion = pd.read_csv(url, usecols=[0,1,4])

datos_seleccion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
#EXPORTAR EL CSV

datos_seleccion.to_csv('/content/drive/MyDrive/CURSO_ALURA/Cruso Pandas E-S: trabajando con diferentes formatos de archivo Pandas E-S: trabajando con diferentes formatos de archivo/clientes_mercado.csv')

# %%
clientes_mercado = pd.read_csv('/content/drive/MyDrive/CURSO_ALURA/Cruso Pandas E-S: trabajando con diferentes formatos de archivo Pandas E-S: trabajando con diferentes formatos de archivo/clientes_mercado.csv')
clientes_mercado
# Out:
#       Unnamed: 0     Id  Year_Birth   Income
# 0              0   1826        1970  84835.0
# 1              1      1        1961  57091.0
# 2              2  10476        1958  67267.0
# 3              3   1386        1967  32474.0
# 4              4   5371        1989  21474.0
# ...          ...    ...         ...      ...
# 2235        2235  10142        1976  66476.0
# 2236        2236   5263        1977  31056.0
# 2237        2237     22        1976  46310.0
# 2238        2238    528        1978  65819.0
# 2239        2239   4070        1969  94871.0
#
# [2240 rows x 4 columns]

# %%
#ELIMINAR LA COLUMNA CON LOS INDICES QUE SE AGREGO AL CSV
datos_seleccion.to_csv('/content/drive/MyDrive/CURSO_ALURA/Cruso Pandas E-S: trabajando con diferentes formatos de archivo Pandas E-S: trabajando con diferentes formatos de archivo/clientes_mercado_sin_indice.csv', index=False)

# %%
datos_seleccion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]
